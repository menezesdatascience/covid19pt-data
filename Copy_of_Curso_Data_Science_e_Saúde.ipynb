# %% [markdown]
# <a href="https://colab.research.google.com/github/menezesdatascience/covid19pt-data/blob/master/Copy_of_Curso_Data_Science_e_Sa%C3%BAde.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# AULA 01 - DADOS E VISUALIZAÇÕES

import pandas as pd

# %%
confirmed = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Confirmed.csv")

# %%
confirmed
# Out:
#     Province/State Country/Region      Lat  ...  3/15/20  3/16/20  3/17/20
# 0              NaN       Thailand  15.0000  ...      114      147    177.0
# 1              NaN          Japan  36.0000  ...      839      825    878.0
# 2              NaN      Singapore   1.2833  ...      226      243    266.0
# 3              NaN          Nepal  28.1667  ...        1        1      1.0
# 4              NaN       Malaysia   2.5000  ...      428      566    673.0
# ..             ...            ...      ...  ...      ...      ...      ...
# 462            NaN       Barbados  13.1939  ...        0        0      2.0
# 463            NaN     Montenegro  42.5000  ...        0        0      2.0
# 464            NaN        Mayotte -12.8275  ...        0        0      1.0
# 465            NaN     The Gambia  13.4667  ...        0        0      1.0
# 466            NaN    Puerto Rico  18.2000  ...        0        0      0.0
#
# [467 rows x 60 columns]

# %%
confirmed.head()
# Out:
#   Province/State Country/Region      Lat  ...  3/15/20  3/16/20  3/17/20
# 0            NaN       Thailand  15.0000  ...      114      147    177.0
# 1            NaN          Japan  36.0000  ...      839      825    878.0
# 2            NaN      Singapore   1.2833  ...      226      243    266.0
# 3            NaN          Nepal  28.1667  ...        1        1      1.0
# 4            NaN       Malaysia   2.5000  ...      428      566    673.0
#
# [5 rows x 60 columns]

# %%
confirmed.shape
# Out:
# (467, 60)

# %%
confirmed["Country/Region"]
# Out:
# 0         Thailand
# 1            Japan
# 2        Singapore
# 3            Nepal
# 4         Malaysia
#           ...
# 462       Barbados
# 463     Montenegro
# 464        Mayotte
# 465     The Gambia
# 466    Puerto Rico
# Name: Country/Region, Length: 467, dtype: object

# %%
last_date = ["3/2/20"]

# %%
confirmed[last_date].head()
# Out:
#    3/2/20
# 0      43
# 1     274
# 2     108
# 3       1
# 4      29

# %%
confirmed["3/2/20"].head()
# Out:
# 0     43
# 1    274
# 2    108
# 3      1
# 4     29
# Name: 3/2/20, dtype: int64

# %%
# retorna valores únicos de cada variável

# %%
confirmed["Country/Region"].unique()
# Out:
# array(['Thailand', 'Japan', 'Singapore', 'Nepal', 'Malaysia', 'Canada',
#        'Australia', 'Cambodia', 'Sri Lanka', 'Germany', 'Finland',
#        'United Arab Emirates', 'Philippines', 'India', 'Italy', 'Sweden',
#        'Spain', 'Belgium', 'Egypt', 'Lebanon', 'Iraq', 'Oman',
#        'Afghanistan', 'Bahrain', 'Kuwait', 'Algeria', 'Croatia',
#        'Switzerland', 'Austria', 'Israel', 'Pakistan', 'Brazil',
#        'Georgia', 'Greece', 'North Macedonia', 'Norway', 'Romania',
#        'Estonia', 'San Marino', 'Belarus', 'Iceland', 'Lithuania',
#        'Mexico', 'New Zealand', 'Nigeria', 'Ireland', 'Luxembourg',
#        'Monaco', 'Qatar', 'Ecuador', 'Azerbaijan', 'Armenia',
#        'Dominican Republic', 'Indonesia', 'Portugal', 'Andorra', 'Latvia',
#        'Morocco', 'Saudi Arabia', 'Senegal', 'Argentina', 'Chile',
#        'Jordan', 'Ukraine', 'Hungary', 'Liechtenstein', 'Poland',
#        'Tunisia', 'Bosnia and Herzegovina', 'Slovenia', 'South Africa',
# ...

# %%
confirmed["Province/State"].unique()
# Out:
# array([nan, 'British Columbia', 'New South Wales', 'Victoria',
#        'Queensland', 'South Australia', 'From Diamond Princess',
#        'Western Australia', 'Tasmania', 'Northern Territory', 'Ontario',
#        'Alberta', 'Quebec', 'Washington', 'New York', 'California',
#        'Massachusetts', 'Diamond Princess', 'Grand Princess', 'Georgia',
#        'Colorado', 'Florida', 'New Jersey', 'Oregon', 'Texas', 'Illinois',
#        'Pennsylvania', 'Iowa', 'Maryland', 'North Carolina',
#        'South Carolina', 'Tennessee', 'Virginia', 'Arizona', 'Indiana',
#        'Kentucky', 'District of Columbia', 'Nevada', 'New Hampshire',
#        'Minnesota', 'Nebraska', 'Ohio', 'Rhode Island', 'Wisconsin',
#        'Connecticut', 'Hawaii', 'Oklahoma', 'Utah', 'Kansas', 'Louisiana',
#        'Missouri', 'Vermont', 'Alaska', 'Arkansas', 'Delaware', 'Idaho',
#        'Maine', 'Michigan', 'Mississippi', 'Montana', 'New Mexico',
#        'North Dakota', 'South Dakota', 'West Virginia', 'Wyoming',
# ...

# %%
confirmed.sample(20)
# Out:
#             Province/State       Country/Region  ...  3/16/20  3/17/20
# 423                    NaN  Trinidad and Tobago  ...        4      5.0
# 441                    NaN  Congo (Brazzaville)  ...        1      1.0
# 270    Okaloosa County, FL                   US  ...        0      NaN
# 370          Multnomah, OR                   US  ...        0      NaN
# 60                     NaN              Andorra  ...        2     39.0
# 55                     NaN           Azerbaijan  ...       15     28.0
# 192                    NaN               Russia  ...       90    114.0
# 68                     NaN               Jordan  ...       17     34.0
# 184               Liaoning                China  ...      125    125.0
# 352             Island, WA                   US  ...        0      NaN
# 330     Norfolk County, MA                   US  ...        0      NaN
# 335       Hillsborough, FL                   US  ...        0      NaN
# ...

# %%
confirmed.head(10)
# Out:
#      Province/State Country/Region      Lat  ...  3/15/20  3/16/20  3/17/20
# 0               NaN       Thailand  15.0000  ...      114      147    177.0
# 1               NaN          Japan  36.0000  ...      839      825    878.0
# 2               NaN      Singapore   1.2833  ...      226      243    266.0
# 3               NaN          Nepal  28.1667  ...        1        1      1.0
# 4               NaN       Malaysia   2.5000  ...      428      566    673.0
# 5  British Columbia         Canada  49.2827  ...       73      103    103.0
# 6   New South Wales      Australia -33.8688  ...      134      171    210.0
# 7          Victoria      Australia -37.8136  ...       57       71     94.0
# 8        Queensland      Australia -28.0167  ...       61       68     78.0
# 9               NaN       Cambodia  11.5500  ...        7        7     33.0
#
# [10 rows x 60 columns]

# %%
confirmed.iloc[0].head(10)
# Out:
# Province/State         NaN
# Country/Region    Thailand
# Lat                     15
# Long                   101
# 1/22/20                  2
# 1/23/20                  3
# 1/24/20                  5
# 1/25/20                  7
# 1/26/20                  8
# 1/27/20                  8
# Name: 0, dtype: object

# %%
confirmed.set_index("Province/State")
# Out:
#                Country/Region      Lat      Long  ...  3/15/20  3/16/20  3/17/20
# Province/State                                    ...
# NaN                  Thailand  15.0000  101.0000  ...      114      147    177.0
# NaN                     Japan  36.0000  138.0000  ...      839      825    878.0
# NaN                 Singapore   1.2833  103.8333  ...      226      243    266.0
# NaN                     Nepal  28.1667   84.2500  ...        1        1      1.0
# NaN                  Malaysia   2.5000  112.5000  ...      428      566    673.0
# ...                       ...      ...       ...  ...      ...      ...      ...
# NaN                  Barbados  13.1939  -59.5432  ...        0        0      2.0
# NaN                Montenegro  42.5000   19.3000  ...        0        0      2.0
# NaN                   Mayotte -12.8275   45.1662  ...        0        0      1.0
# NaN                The Gambia  13.4667  -16.6000  ...        0        0      1.0
# ...

# %%
confirmed.set_index("Province/State").iloc[1]
# Out:
# Country/Region    Japan
# Lat                  36
# Long                138
# 1/22/20               2
# 1/23/20               1
# 1/24/20               2
# 1/25/20               2
# 1/26/20               4
# 1/27/20               4
# 1/28/20               7
# 1/29/20               7
# 1/30/20              11
# 1/31/20              15
# 2/1/20               20
# 2/2/20               20
# 2/3/20               20
# 2/4/20               22
# 2/5/20               22
# 2/6/20               45
# 2/7/20               25
# 2/8/20               25
# 2/9/20               26
# 2/10/20              26
# 2/11/20              26
# 2/12/20              28
# 2/13/20              28
# 2/14/20              29
# 2/15/20              43
# 2/16/20              59
# 2/17/20              66
# 2/18/20              74
# 2/19/20              84
# 2/20/20              94
# 2/21/20             105
# 2/22/20             122
# 2/23/20             147
# 2/24/20             159
# 2/25/20             170
# ...

# %%
confirmed["Country/Region"]
# Out:
# 0         Thailand
# 1            Japan
# 2        Singapore
# 3            Nepal
# 4         Malaysia
#           ...
# 462       Barbados
# 463     Montenegro
# 464        Mayotte
# 465     The Gambia
# 466    Puerto Rico
# Name: Country/Region, Length: 467, dtype: object

# %%
confirmed["Country/Region"].value_counts()
# valor é falso, pois o erro é muito grande;
# não vou considerar essa análise, pois há muitos valores com disparidades no padrão;
# Out:
# US                          247
# China                        33
# Canada                       11
# Australia                     9
# France                        8
#                            ...
# Ethiopia                      1
# Montenegro                    1
# Central African Republic      1
# Brazil                        1
# French Guiana                 1
# Name: Country/Region, Length: 159, dtype: int64

# %%
confirmed_by_country = confirmed.groupby("Country/Region").sum()
confirmed_by_country
# Out:
#                                     Lat      Long  ...  3/16/20  3/17/20
# Country/Region                                     ...
# Afghanistan                     33.0000   65.0000  ...       21     22.0
# Albania                         41.1533   20.1683  ...       51     55.0
# Algeria                         28.0339    1.6596  ...       54     60.0
# Andorra                         42.5063    1.5218  ...        2     39.0
# Antigua and Barbuda             17.0608  -61.7964  ...        1      1.0
# ...                                 ...       ...  ...      ...      ...
# Uruguay                        -32.5228  -55.7658  ...        8     29.0
# Uzbekistan                      41.3775   64.5853  ...        6     10.0
# Venezuela                        6.4238  -66.5897  ...       17     33.0
# Vietnam                         16.0000  108.0000  ...       61     66.0
# occupied Palestinian territory  31.9522   35.2332  ...        0      0.0
#
# [159 rows x 58 columns]

# %%
confirmed_by_country.head()
# Out:
#                          Lat     Long  1/22/20  ...  3/15/20  3/16/20  3/17/20
# Country/Region                                  ...
# Afghanistan          33.0000  65.0000        0  ...       16       21     22.0
# Albania              41.1533  20.1683        0  ...       42       51     55.0
# Algeria              28.0339   1.6596        0  ...       48       54     60.0
# Andorra              42.5063   1.5218        0  ...        1        2     39.0
# Antigua and Barbuda  17.0608 -61.7964        0  ...        1        1      1.0
#
# [5 rows x 58 columns]

# %%
confirmed_by_country.sample(10)
# .sample, irá escolher aleatoriamente 10 valores, ao contrário de .head(10), por exemplo que irá demonstrar os 10 primeiros valores, as 10 primeiras linhas.
# Out:
#                           Lat      Long  1/22/20  ...  3/15/20  3/16/20  3/17/20
# Country/Region                                    ...
# Kazakhstan            48.0196   66.9237        0  ...        9       10     33.0
# Mauritania            21.0079   10.9408        0  ...        1        1      1.0
# Antigua and Barbuda   17.0608  -61.7964        0  ...        1        1      1.0
# Barbados              13.1939  -59.5432        0  ...        0        0      2.0
# Bangladesh            23.6850   90.3563        0  ...        5        8     10.0
# Canada               542.6529 -977.7832        0  ...      252      415    478.0
# Croatia               45.1000   15.2000        0  ...       49       57     65.0
# Iran                  32.0000   53.0000        0  ...    13938    14991  16169.0
# Hungary               47.1625   19.5033        0  ...       32       39     50.0
# Ukraine               48.3794   31.1656        0  ...        3        7     14.0
#
# [10 rows x 58 columns]

# %%
confirmed_by_country.sample(10)
# Out:
#                                     Lat      Long  ...  3/16/20  3/17/20
# Country/Region                                     ...
# Romania                         45.9432   24.9668  ...      158    184.0
# Malta                           35.9375   14.3754  ...       30     38.0
# Tunisia                         34.0000    9.0000  ...       20     24.0
# Cote d'Ivoire                    7.5400   -5.5471  ...        1      5.0
# Indonesia                       -0.7893  113.9213  ...      134    172.0
# Finland                         64.0000   26.0000  ...      277    321.0
# Saudi Arabia                    24.0000   45.0000  ...      118    171.0
# occupied Palestinian territory  31.9522   35.2332  ...        0      0.0
# Poland                          51.9194   19.1451  ...      177    238.0
# Taiwan*                         23.7000  121.0000  ...       67     77.0
#
# [10 rows x 58 columns]

# %%
confirmed_by_country.loc["Cameroon"][15:]
# Out:
# 2/4/20      0.0
# 2/5/20      0.0
# 2/6/20      0.0
# 2/7/20      0.0
# 2/8/20      0.0
# 2/9/20      0.0
# 2/10/20     0.0
# 2/11/20     0.0
# 2/12/20     0.0
# 2/13/20     0.0
# 2/14/20     0.0
# 2/15/20     0.0
# 2/16/20     0.0
# 2/17/20     0.0
# 2/18/20     0.0
# 2/19/20     0.0
# 2/20/20     0.0
# 2/21/20     0.0
# 2/22/20     0.0
# 2/23/20     0.0
# 2/24/20     0.0
# 2/25/20     0.0
# 2/26/20     0.0
# 2/27/20     0.0
# 2/28/20     0.0
# 2/29/20     0.0
# 3/1/20      0.0
# 3/2/20      0.0
# 3/3/20      0.0
# 3/4/20      0.0
# 3/5/20      0.0
# 3/6/20      1.0
# 3/7/20      1.0
# 3/8/20      2.0
# 3/9/20      2.0
# 3/10/20     2.0
# 3/11/20     2.0
# 3/12/20     2.0
# 3/13/20     2.0
# 3/14/20     2.0
# 3/15/20     2.0
# 3/16/20     4.0
# 3/17/20    10.0
# Name: Cameroon, dtype: float64

# %%
confirmed_by_country
# Out:
#                                     Lat      Long  ...  3/16/20  3/17/20
# Country/Region                                     ...
# Afghanistan                     33.0000   65.0000  ...       21     22.0
# Albania                         41.1533   20.1683  ...       51     55.0
# Algeria                         28.0339    1.6596  ...       54     60.0
# Andorra                         42.5063    1.5218  ...        2     39.0
# Antigua and Barbuda             17.0608  -61.7964  ...        1      1.0
# ...                                 ...       ...  ...      ...      ...
# Uruguay                        -32.5228  -55.7658  ...        8     29.0
# Uzbekistan                      41.3775   64.5853  ...        6     10.0
# Venezuela                        6.4238  -66.5897  ...       17     33.0
# Vietnam                         16.0000  108.0000  ...       61     66.0
# occupied Palestinian territory  31.9522   35.2332  ...        0      0.0
#
# [159 rows x 58 columns]

# %%
confirmed_by_country.loc["US"][2:]
# Out:
# 1/22/20       1.0
# 1/23/20       1.0
# 1/24/20       2.0
# 1/25/20       2.0
# 1/26/20       5.0
# 1/27/20       5.0
# 1/28/20       5.0
# 1/29/20       5.0
# 1/30/20       5.0
# 1/31/20       7.0
# 2/1/20        8.0
# 2/2/20        8.0
# 2/3/20       11.0
# 2/4/20       11.0
# 2/5/20       11.0
# 2/6/20       11.0
# 2/7/20       11.0
# 2/8/20       11.0
# 2/9/20       11.0
# 2/10/20      11.0
# 2/11/20      12.0
# 2/12/20      12.0
# 2/13/20      13.0
# 2/14/20      13.0
# 2/15/20      13.0
# 2/16/20      13.0
# 2/17/20      13.0
# 2/18/20      13.0
# 2/19/20      13.0
# 2/20/20      13.0
# 2/21/20      15.0
# 2/22/20      15.0
# 2/23/20      15.0
# 2/24/20      51.0
# 2/25/20      51.0
# 2/26/20      57.0
# 2/27/20      58.0
# 2/28/20      60.0
# 2/29/20      68.0
# 3/1/20       74.0
# 3/2/20       98.0
# 3/3/20      118.0
# 3/4/20      149.0
# 3/5/20      217.0
# 3/6/20      262.0
# 3/7/20      402.0
# 3/8/20      518.0
# 3/9/20      583.0
# 3/10/20     959.0
# 3/11/20    1281.0
# ...

# %%
confirmed_by_country.loc["US"][2:].plot()

# %%
confirmed_by_country.loc["Algeria"][2:].plot()

# %%
import matplotlib.pyplot as plt
confirmed_by_country.loc["Algeria"][2:].plot()
plt.title("Casos confirmados em 'Algeria'")
# Out:
# Text(0.5, 1.0, "Casos confirmados em 'Algeria'")

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
confirmed_by_country.loc["US"][2:].plot()
plt.title("Casos confirmados em 'US'")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.figure(figsize=(10,5))
confirmed_by_country.loc["US"][45:].plot()
plt.title("Casos confirmados em 'US'")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.figure(figsize=(12
                    ,5))
confirmed_by_country.loc["US"][45:].plot()
plt.title("Casos confirmados em 'US'")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# gráficos muito estreitos passam uma imagem extremamente fora da realidade em relação ao gráfico acima.
plt.figure(figsize=(5,5))
confirmed_by_country.loc["US"][45:50].plot()
plt.title("Casos confirmados em 'US'")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.figure(figsize=(10,5))
confirmed_by_country.loc["US"][2:30].plot()
plt.title("Casos confirmados em 'US'")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.figure(figsize=(10,5))
confirmed_by_country.loc["US"][2:30].plot()
plt.title("Casos confirmados em 'US'")
plt.ylim(8,12)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# ylim: é possível alterar o limite no eixo "y", alterando assim a disposição do gráfico em relação ao eixo em relação.
confirmed_by_country.loc["US"][2:].plot()
plt.title("Gráfico ERRADO, sem informações PERTINENTES para essa análise 'US'")
plt.xlim(1/22/20, 2/11/20)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
# AULA 02 - TIME SERIES, TORTAS E BARRAS
confirmed_by_country.loc['US'][2:].diff
# Out:
# <bound method Series.diff of 1/22/20       1.0
# 1/23/20       1.0
# 1/24/20       2.0
# 1/25/20       2.0
# 1/26/20       5.0
# 1/27/20       5.0
# 1/28/20       5.0
# 1/29/20       5.0
# 1/30/20       5.0
# 1/31/20       7.0
# 2/1/20        8.0
# 2/2/20        8.0
# 2/3/20       11.0
# 2/4/20       11.0
# 2/5/20       11.0
# 2/6/20       11.0
# 2/7/20       11.0
# 2/8/20       11.0
# 2/9/20       11.0
# 2/10/20      11.0
# 2/11/20      12.0
# 2/12/20      12.0
# 2/13/20      13.0
# 2/14/20      13.0
# 2/15/20      13.0
# 2/16/20      13.0
# 2/17/20      13.0
# 2/18/20      13.0
# 2/19/20      13.0
# 2/20/20      13.0
# 2/21/20      15.0
# 2/22/20      15.0
# 2/23/20      15.0
# 2/24/20      51.0
# 2/25/20      51.0
# 2/26/20      57.0
# 2/27/20      58.0
# 2/28/20      60.0
# 2/29/20      68.0
# 3/1/20       74.0
# 3/2/20       98.0
# 3/3/20      118.0
# 3/4/20      149.0
# 3/5/20      217.0
# 3/6/20      262.0
# 3/7/20      402.0
# 3/8/20      518.0
# 3/9/20      583.0
# ...

# %%
confirmações_por_país_diferença_dia_a_dia = confirmed_by_country.loc['US'][2:].diff().dropna()
confirmações_por_país_diferença_dia_a_dia
# Out:
# 1/23/20       0.0
# 1/24/20       1.0
# 1/25/20       0.0
# 1/26/20       3.0
# 1/27/20       0.0
# 1/28/20       0.0
# 1/29/20       0.0
# 1/30/20       0.0
# 1/31/20       2.0
# 2/1/20        1.0
# 2/2/20        0.0
# 2/3/20        3.0
# 2/4/20        0.0
# 2/5/20        0.0
# 2/6/20        0.0
# 2/7/20        0.0
# 2/8/20        0.0
# 2/9/20        0.0
# 2/10/20       0.0
# 2/11/20       1.0
# 2/12/20       0.0
# 2/13/20       1.0
# 2/14/20       0.0
# 2/15/20       0.0
# 2/16/20       0.0
# 2/17/20       0.0
# 2/18/20       0.0
# 2/19/20       0.0
# 2/20/20       0.0
# 2/21/20       2.0
# 2/22/20       0.0
# 2/23/20       0.0
# 2/24/20      36.0
# 2/25/20       0.0
# 2/26/20       6.0
# 2/27/20       1.0
# 2/28/20       2.0
# 2/29/20       8.0
# 3/1/20        6.0
# 3/2/20       24.0
# 3/3/20       20.0
# 3/4/20       31.0
# 3/5/20       68.0
# 3/6/20       45.0
# 3/7/20      140.0
# 3/8/20      116.0
# 3/9/20       65.0
# 3/10/20     376.0
# 3/11/20     322.0
# 3/12/20     382.0
# ...

# %%
confirmações_por_país_diferença_dia_a_dia.plot()

# %%
confirmações_por_país_diferença_dia_a_dia.plot()
plt.figure(figsize=(15,5))

# %%
plt.figure(figsize=(15,5))
confirmações_por_país_diferença_dia_a_dia.plot()

# %%
last_date_cases = confirmed_by_country[last_date]
last_date_cases.plot()
plt.title("Last Date Cases")
plt.Figure(figsize=(5,5))

# %%
last_date_cases = confirmed_by_country[last_date]
last_date_cases.plot()
plt.title("Last Date by Confirmad Cases")
plt.Figure(figsize=(15,5))

# %%
confirmed_by_country[last_date].plot()
plt.title("Last Date by Confirmad Cases")
plt.Figure(figsize=(15,5))

# %%
confirmed_by_country[last_date].sort_values(by='weight')[0:20].plot(kind='bar')
plt.title("Last Date by Confirmad Cases")
plt.show
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-46-4f7c72a89287> in <module>()
# ----> 1 confirmed_by_country[last_date].sort_values(by='weight')[0:20].plot(kind='bar')
#       2 plt.title("Last Date by Confirmad Cases")
#       3 plt.show
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/frame.py in sort_values(self, by, axis, ascending, inplace, kind, na_position)
#    5006
#    5007             by = by[0]
# -> 5008             k = self._get_label_or_level_values(by, axis=axis)
#    5009
#    5010             if isinstance(ascending, (tuple, list)):
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/generic.py in _get_label_or_level_values(self, key, axis)
#    1772             values = self.axes[axis].get_level_values(key)._values
#    1773         else:
# -> 1774             raise KeyError(key)
#    1775
#    1776         # Check for duplicates
#
# ...

# %%
confirmed_by_country.loc["US"][2:].plot()

# %%
confirmed_by_country.loc["US"][2:].plot()
plt.title("Casos Confirmados, continuação da aula, teste google colab X jupter notebook")
# Out:
# Text(0.5, 1.0, 'Casos Confirmados, continuação da aula, teste google colab X jupter notebook')

# %%
confirmed_by_country[last_date].sort_values(ascending=False)[0,10].plot()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-52-19da18de2ec3> in <module>()
# ----> 1 confirmed_by_country[last_date].sort_values(ascending=False)[0,10].plot()
#
# TypeError: sort_values() missing 1 required positional argument: 'by'

# %%
confirmed_by_country[last_date][:10].plot(kind='bar')
plt.figure(figsize=(15,5))
plt.show()

# %%
plt.figure(figsize=(35,5))
confirmed_by_country[last_date][:10].plot(kind='bar')
plt.show()
# figsize não está alterando o tamanho do gráfico.

# %% [markdown]
# AULA - 03 - Fontes de dados e letalidade
#
# 01 Fonte de dados

# %%
deaths = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Deaths.csv")

# %%
deaths
# Out:
#     Province/State Country/Region      Lat  ...  3/15/20  3/16/20  3/17/20
# 0              NaN       Thailand  15.0000  ...        1        1      1.0
# 1              NaN          Japan  36.0000  ...       22       27     29.0
# 2              NaN      Singapore   1.2833  ...        0        0      0.0
# 3              NaN          Nepal  28.1667  ...        0        0      0.0
# 4              NaN       Malaysia   2.5000  ...        0        0      2.0
# ..             ...            ...      ...  ...      ...      ...      ...
# 462            NaN       Barbados  13.1939  ...        0        0      0.0
# 463            NaN     Montenegro  42.5000  ...        0        0      0.0
# 464            NaN        Mayotte -12.8275  ...        0        0      0.0
# 465            NaN     The Gambia  13.4667  ...        0        0      0.0
# 466            NaN    Puerto Rico  18.2000  ...        0        0      0.0
#
# [467 rows x 60 columns]

# %%
recovered = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_19-covid-Recovered.csv")

# %%
recovered
# Out:
#     Province/State Country/Region      Lat  ...  3/15/20  3/16/20  3/17/20
# 0              NaN       Thailand  15.0000  ...       35       35     41.0
# 1              NaN          Japan  36.0000  ...      118      144    144.0
# 2              NaN      Singapore   1.2833  ...      105      109    114.0
# 3              NaN          Nepal  28.1667  ...        1        1      1.0
# 4              NaN       Malaysia   2.5000  ...       42       42     49.0
# ..             ...            ...      ...  ...      ...      ...      ...
# 462            NaN       Barbados  13.1939  ...        0        0      0.0
# 463            NaN     Montenegro  42.5000  ...        0        0      0.0
# 464            NaN        Mayotte -12.8275  ...        0        0      0.0
# 465            NaN     The Gambia  13.4667  ...        0        0      0.0
# 466            NaN    Puerto Rico  18.2000  ...        0        0      0.0
#
# [467 rows x 60 columns]

# %%
display(deaths.head())
display(recovered.head())
# Out:
#   Province/State Country/Region      Lat  ...  3/15/20  3/16/20  3/17/20
# 0            NaN       Thailand  15.0000  ...        1        1      1.0
# 1            NaN          Japan  36.0000  ...       22       27     29.0
# 2            NaN      Singapore   1.2833  ...        0        0      0.0
# 3            NaN          Nepal  28.1667  ...        0        0      0.0
# 4            NaN       Malaysia   2.5000  ...        0        0      2.0
#
# [5 rows x 60 columns]
#   Province/State Country/Region      Lat  ...  3/15/20  3/16/20  3/17/20
# 0            NaN       Thailand  15.0000  ...       35       35     41.0
# 1            NaN          Japan  36.0000  ...      118      144    144.0
# 2            NaN      Singapore   1.2833  ...      105      109    114.0
# 3            NaN          Nepal  28.1667  ...        1        1      1.0
# 4            NaN       Malaysia   2.5000  ...       42       42     49.0
#
# [5 rows x 60 columns]

# %%
confirmed_by_groupby("Country/Region").sum()[last_date].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-83-4cac93d142d1> in <module>()
# ----> 1 confirmed_by_groupby("Country/Region").sum()[last_date].head()
#
# NameError: name 'confirmed_by_groupby' is not defined
